# %%
import requests

# %%
r = requests.get(r'https://images.unsplash.com/photo-1657214059493-986710bc4788?ixlib=rb-4.0.3&ixid=MnwxMjA3fDF8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1170&q=80')

# %%
with open('test.png', 'wb') as f:
    f.write(r.content)

# %%
import pandas as pd
import time
df = pd.read_csv(r'/home/dingo/code/internship_projects/Internship_projects/instagram_influencer_image_classification/data/influencial/influencial_links.csv')

# %%
# print(df['links'])
df = df[50:]
df
# Out:
#                                                 links
# 50  https://images.unsplash.com/photo-158540967798...
# 51  https://images.unsplash.com/photo-153056967347...
# 52  https://images.unsplash.com/photo-158940585886...
# 53  https://images.unsplash.com/photo-158750262437...
# 54  https://images.unsplash.com/photo-150511838075...
# 55  https://images.unsplash.com/photo-143940532685...
# 56  https://images.unsplash.com/photo-150375623450...
# 57  https://images.unsplash.com/photo-150647733147...
# 58  https://images.unsplash.com/photo-145719574089...
# 59  https://images.unsplash.com/photo-1548032885-b...
# 60  https://images.unsplash.com/photo-1546069901-b...
# 61  https://images.unsplash.com/photo-150467490024...
# 62  https://images.unsplash.com/photo-1555939594-5...
# 63  https://images.unsplash.com/photo-156529962494...
# 64  https://images.unsplash.com/photo-156762090573...
# 65  https://images.unsplash.com/photo-160678736685...
# ...

# %%
count = 50
for link in df['links']:
    r = requests.get(str(link))
    with open(f'data/influencial/influencial{count}.png', 'wb') as f:
        f.write(r.content)
    count += 1
